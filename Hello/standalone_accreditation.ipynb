# %%
import pandas as pd

# %%
top_standalone_accreditation_2017=pd.read_csv("C:\\Users\\sanya\\OneDrive\\Desktop\\SIH2022\\Hello\\standalone_accreditation_2017")

# %%
top_standalone_accreditation_2018=pd.read_csv("C:\\Users\\sanya\\OneDrive\\Desktop\\SIH2022\\Hello\\standalone_accreditation_2018")

# %%
top_standalone_accreditation_2019=pd.read_csv("C:\\Users\\sanya\\OneDrive\\Desktop\\SIH2022\\Hello\\standalone_accreditation_2019")

# %%
frame = [top_standalone_accreditation_2017,top_standalone_accreditation_2018,top_standalone_accreditation_2019]

# %%
top_standalone_accreditation=pd.concat(frame)

# %%
top_standalone_accreditation
# Out:
#    Unnamed: 0 AISHE Code                        Standalone Institution Name  \
# 0         313     S-3868                                 NANDA HOSPITAL UNA
# 1         209    S-16221                         Westbank School of Nursing
# 2         134    S-15457  Govt. Nursing Training School, Civil Hospital ...
# 3         517     S-4564         S U T SCHOOL OF NURSING THIRUVANANTHAPURAM
# 4         272    S-13934  GINNI DEVI ACTION SCHOOL OF NURSING, PASCHIM V...
# 5         135    S-15457  Govt. Nursing Training School, Civil Hospital ...
# 6         525     S-4528          MARY IMMACULATE SCHOOL OF NURSING TRICHUR
# 7         567     S-4621               ST RITA'S SCHOOL OF NURSING KOTTAYAM
# 8          85    S-14024              ANM SCHOOL, SANSKAR TIRTH- AJOL, AJOL
# 9         216     S-5586  DISTRICT INSTITUTE OF EDUCATION & TRAINING (DI...
# 0          95    S-17995  Matoshri Nursing School R.A.N.M. (M.H.W.), Par...
# ...
