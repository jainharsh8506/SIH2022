# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_top_accreditation_2018 = pd.read_csv("C:\\Users\\ACSS\\Desktop\\SIH2022\\Hello\\top_10_accreditation_2018")

# %%
df_top_accreditation_2017 = pd.read_csv("C:\\Users\\ACSS\\Desktop\\SIH2022\\Hello\\top_10_accreditation_2017")

# %%
df_top_accreditation_2019 = pd.read_csv("C:\\Users\\ACSS\\Desktop\\SIH2022\\Hello\\top_10_accreditation_2019")
df_top_accreditation_2019
# Out:
#    Unnamed: 0  university_id  \
# 0         582             41
# 1         586            500
# 2         576            109
# 3         185            222
# 4         384            503
# 5          64             37
# 6         315             35
# 7         268            467
# 8         241            331
# 9         336            573
#
#                                                 name aishe_code  \
# 0  The English and Foreign Languages University, ...     U-0041
# 1                  Banaras Hindu University, Banaras     U-0500
# 2                       Jawahar Lal Nehru University     U-0109
# 3         JSS ACADEMY OF HIGHER EDUCATION & RESEARCH     U-0222
# 4  Central Institute of Higher Tibetan Studies, V...     U-0503
# 5             Sri Venkateswara University, Tirupathy     U-0037
# 6  Sri Satya Sai Institute of Higher Learning, An...     U-0035
# 7   National Institute of Technology, Tiruchirapalli     U-0467
# ...

# %%
frames=[df_top_accreditation_2017,df_top_accreditation_2018,df_top_accreditation_2019]

# %%
df_result=pd.concat(frames)
df_result
# Out:
#    Unnamed: 0  university_id  \
# 0         189             41
# 1         350            553
# 2         174             35
# 3         227            500
# 4         335            331
# 5         132            573
# 6         243            153
# 7         430            277
# 8         246            308
# 9         144            109
# 0         176            553
# 1         499             72
# 2         140            265
# 3         527             37
# 4         394             35
# 5         212            350
# 6         365             17
# 7         491            109
# 8         351            467
# 9         457            500
# 0         582             41
# 1         586            500
# 2         576            109
# 3         185            222
# 4         384            503
# 5          64             37
# 6         315             35
# 7         268            467
# 8         241            331
# 9         336            573
#
# ...

# %%
df_result.rename(columns={"survey_year_x" : "Survey_Year","percentage":"Percentage", "name":"College_name"}, inplace = True)

# %%
df_result_final=df_result.drop(['Unnamed: 0','infrastructure_id','has_score','score','max_score','accreditation_body'],axis=1)

# %%
df_1=df_result_final.query("College_name == 'Jawahar Lal Nehru University'")

# %%
df_1
# Out:
#    university_id                  College_name aishe_code  Survey_Year  \
# 9            109  Jawahar Lal Nehru University     U-0109         2017
# 7            109  Jawahar Lal Nehru University     U-0109         2018
# 2            109  Jawahar Lal Nehru University     U-0109         2019
#
#    Percentage
# 9       94.25
# 7      100.00
# 2      100.00

# %%
X=df_1.iloc[:, 3:4].values
Y=df_1.iloc[: , 4].values

# %%
print(X)
# Out:
# [[2017]
#  [2018]
#  [2019]]

# %%
print(Y)
plt.scatter(X,Y)
plt.show()
# Out:
# [ 94.25 100.   100.  ]

# %%
from sklearn.linear_model import LinearRegression
lin = LinearRegression()

# %%
lin.fit(X, Y)
# Out:
# LinearRegression()

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly= PolynomialFeatures(degree=1)

# %%
X_poly=poly.fit_transform(X)

# %%
poly.fit(X_poly, Y)
lin2 = LinearRegression()
lin2.fit(X_poly, Y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, Y, color = 'blue')
  
plt.plot(X, lin.predict(X), color = 'red')
plt.title('Linear Regression')
plt.xlabel('YEAR')
plt.ylabel('SCORE')
  
plt.show()

# %%
plt.scatter(X,Y,color='red')

# %%
plt.plot(X, lin2.predict(poly.fit_transform(X)), color = 'red')
plt.title('Polynomial Regression')
plt.xlabel('Survey_Year')
plt.ylabel('Percentage')
plt.show()

# %% [markdown]
# POLYNOMIAL REGRESSION

# %%
pred = 2020
predarray = np.array([[pred]])
print(lin.predict(predarray))
# Out:
# [103.83333333]

# %% [markdown]
# LINEAR REGRESSION

# %%
pred2 = 2020
pred2array = np.array([[pred2]])
print(lin2.predict(poly.fit_transform(pred2array)))
# Out:
# [100.]
