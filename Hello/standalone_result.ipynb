# %%
import pandas as pd

# %%
top_standalone_result_2017=pd.read_csv("C:\\Users\\sanya\\OneDrive\\Desktop\\SIH2022\\Hello\\standalone_result_2017")

# %%
top_standalone_result_2018=pd.read_csv("C:\\Users\\sanya\\OneDrive\\Desktop\\SIH2022\\Hello\\standalone_result_2018")

# %%
top_standalone_result_2019=pd.read_csv("C:\\Users\\sanya\\OneDrive\\Desktop\\SIH2022\\Hello\\standalone_result_2019")

# %%
filter=[top_standalone_result_2017,top_standalone_result_2018,top_standalone_result_2019]

# %%
top_standalone_result=pd.concat(filter)

# %%
top_standalone_result
# Out:
#    Unnamed: 0 AISHE Code                        Standalone Institution Name  \
# 0        4900     S-4911       BENGAL HEALTH INSTITUTE OF SCIENCES LUDHIANA
# 1        4630     S-2178  SHRI SIDDHESHWAR DEOSTHAN TRUST'S SIDDHESHWAR ...
# 2        4600     S-4503                   LISA SCHOOL OF NURSING KOZHIKODE
# 3        4616     S-2094  SEVADAS SHIKSHAN PRASARAK MANDAL'S VASANTRAO N...
# 4        4617     S-2094  SEVADAS SHIKSHAN PRASARAK MANDAL'S VASANTRAO N...
# 5        4623     S-4299  SMT NARAYANI D R KARIGOWDA SCHOOL OF NURSING H...
# 6        3802    S-15521                    School of Public Health Nursing
# 7        3799    S-15817              JANAKI INSTITUE OF NURSING  EDUCATION
# 8        4624     S-4299  SMT NARAYANI D R KARIGOWDA SCHOOL OF NURSING H...
# 9        4625     S-4471                    GOVT SCHOOL OF NURSING KOTTAYAM
# 0        4997    S-17856          Dr.Prafulla Patil Nursing School Parbhani
# ...
